# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# ##### 1. Energy Consumption per Grid Area in Denmark
#
# https://www.energidataservice.dk/tso-electricity/ConsumptionPerGridarea

# %%
energy = response = requests.get(url='https://api.energidataservice.dk/dataset/ConsumptionPerGridarea?limit=10000')

# %%
energy.status_code # Check if ok. 200 means all good
# Out:
# 200

# %%
#energy.content
#energy.json()  Energy is a json

# %%
energy_data = pd.DataFrame(energy.json())
energy_data.head()
# As wee see al information is in records column. We need it to extract it an make it a df
# Out:
#      total  limit                 dataset  \
# 0  3792805  10000  ConsumptionPerGridarea
# 1  3792805  10000  ConsumptionPerGridarea
# 2  3792805  10000  ConsumptionPerGridarea
# 3  3792805  10000  ConsumptionPerGridarea
# 4  3792805  10000  ConsumptionPerGridarea
#
#                                              records
# 0  {'HourUTC': '2022-12-26T22:00:00', 'HourDK': '...
# 1  {'HourUTC': '2022-12-26T22:00:00', 'HourDK': '...
# 2  {'HourUTC': '2022-12-26T22:00:00', 'HourDK': '...
# 3  {'HourUTC': '2022-12-26T22:00:00', 'HourDK': '...
# 4  {'HourUTC': '2022-12-26T22:00:00', 'HourDK': '...

# %%
energy_data['records']
dict(energy_data['records'])
pd.DataFrame(dict(energy_data['records'])).T
# Out:
#                   HourUTC               HourDK GridCompany  \
# 0     2022-12-26T22:00:00  2022-12-26T23:00:00         003
# 1     2022-12-26T22:00:00  2022-12-26T23:00:00         007
# 2     2022-12-26T22:00:00  2022-12-26T23:00:00         016
# 3     2022-12-26T22:00:00  2022-12-26T23:00:00         031
# 4     2022-12-26T22:00:00  2022-12-26T23:00:00         042
# ...                   ...                  ...         ...
# 9995  2022-12-18T22:00:00  2022-12-18T23:00:00         152
# 9996  2022-12-18T22:00:00  2022-12-18T23:00:00         154
# 9997  2022-12-18T22:00:00  2022-12-18T23:00:00         233
# 9998  2022-12-18T22:00:00  2022-12-18T23:00:00         244
# 9999  2022-12-18T22:00:00  2022-12-18T23:00:00         245
#
#      ResidualConsumption FlexSettledConsumption HourlySettledConsumption
# 0                   None           89193.890625                      0.0
# 1                   None           47475.890625                      0.0
# ...

# %% [markdown]
# ##### 2. Crypto Exchange
#
# https://docs.coincap.io/

# %%
crypto = requests.get("https://api.coincap.io/v2/assets")

# %%
crypto.status_code
# Out:
# 200

# %%
#crypto.content

# %%
crypto_data = pd.DataFrame(crypto.json())
crypto_data.head() # Again. All information is in data column. We need to extract it
# Out:
#                                                 data      timestamp
# 0  {'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC'...  1673419251543
# 1  {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH...  1673419251543
# 2  {'id': 'tether', 'rank': '3', 'symbol': 'USDT'...  1673419251543
# 3  {'id': 'binance-coin', 'rank': '4', 'symbol': ...  1673419251543
# 4  {'id': 'usd-coin', 'rank': '5', 'symbol': 'USD...  1673419251543

# %%
crypto_data['data']
dict(crypto_data['data'])
pd.DataFrame(dict(crypto_data['data'])).transpose()
# Out:
#                id rank symbol           name                        supply  \
# 0         bitcoin    1    BTC        Bitcoin     19258687.0000000000000000
# 1        ethereum    2    ETH       Ethereum    122373866.2178000000000000
# 2          tether    3   USDT         Tether  66272586693.3717000000000000
# 3    binance-coin    4    BNB            BNB    166801148.0000000000000000
# 4        usd-coin    5   USDC       USD Coin  43720276900.4764400000000000
# ..            ...  ...    ...            ...                           ...
# 95     gnosis-gno   96    GNO         Gnosis      2589588.0000000000000000
# 96          iotex   97   IOTX          IoTeX   9420805889.0000000000000000
# 97  oasis-network   98   ROSE  Oasis Network   5725718533.0000000000000000
# 98         kusama   99    KSM         Kusama      8470098.0572620600000000
# 99           qtum  100   QTUM           Qtum    104489218.5000000000000000
#
#                        maxSupply                   marketCapUsd  \
# ...

# %% [markdown]
# ##### 3. Tenders in Spain
#
# https://tenders.guru/es/api

# %%
tenders = requests.get('https://tenders.guru/api/es/tenders')

# %%
tenders.status_code
# Out:
# 200

# %%
#tenders.content

# %%
tenders_data = pd.DataFrame(tenders.json())
tenders_data.head()
# Out:
#    page_count  page_number  page_size   total  \
# 0        7146            1        100  714598
# 1        7146            1        100  714598
# 2        7146            1        100  714598
# 3        7146            1        100  714598
# 4        7146            1        100  714598
#
#                                                 data
# 0  {'id': '831333', 'date': '2021-06-29', 'deadli...
# 1  {'id': '831322', 'date': '2021-05-17', 'deadli...
# 2  {'id': '831319', 'date': '2021-06-29', 'title'...
# 3  {'id': '831318', 'date': '2021-06-29', 'title'...
# 4  {'id': '831317', 'date': '2021-05-26', 'deadli...

# %%
tenders_data['data']
dict(tenders_data['data'])
pd.DataFrame(dict(tenders_data['data']))
pd.DataFrame(dict(tenders_data['data'])).transpose()
# Out:
#         id        date deadline_date deadline_length_days  \
# 0   831333  2021-06-29    2021-06-07                   22
# 1   831322  2021-05-17    2021-06-01                   15
# 2   831319  2021-06-29           NaN                  NaN
# 3   831318  2021-06-29           NaN                  NaN
# 4   831317  2021-05-26    2021-06-11                   16
# ..     ...         ...           ...                  ...
# 95  830910  2021-06-28    2021-06-29                    1
# 96  830897  2021-06-28    2021-06-16                   12
# 97  830884  2021-05-04    2021-05-25                   21
# 98  830883  2021-06-09    2021-06-24                   15
# 99  830875  2021-06-02    2021-06-14                   12
#
#                                                 title  category      sid  \
# 0   Servicio de producción de células mesenquimale...  services  7791427
# 1   Contratación de Servicio de la Programación de...  services  7554969
# ...

# %%
# We could already analize which categories are more frequent. Further cleaning would be needed. One interesting project might be mergin all the datasets of teners in the EU.
